# %%
import pandas as pd
import numpy as np

from datetime import date

# %%
data = "Resources/us_foreign_aid_complete.csv"

# %%
foreignaid = pd.read_csv(data, low_memory=False)
print(foreignaid.shape)
# Out:
# (1174113, 49)

# %%
df = pd.DataFrame(foreignaid)

# %%
start_date = "2015"
end_date= "2019"

# %%
df_filtered = df[df['fiscal_year'] > '2015']
df_filtered
# Out:
#          country_id country_code country_name  region_id  \
# 14                4          AFG  Afghanistan          4
# 18                4          AFG  Afghanistan          4
# 21                4          AFG  Afghanistan          4
# 24                4          AFG  Afghanistan          4
# 28                4          AFG  Afghanistan          4
# ...             ...          ...          ...        ...
# 1173900         204          BEN        Benin          5
# 1173912        1002          WLD        World          7
# 1173993         288          GHA        Ghana          5
# 1173995        1002          WLD        World          7
# 1174057           4          AFG  Afghanistan          4
#
#                     region_name  income_group_id            income_group_name  \
# 14       South and Central Asia              1.0           Low Income Country
# 18       South and Central Asia              1.0           Low Income Country
# ...

# %%
test=df_filtered.dropna()
test
# Out:
#          country_id country_code country_name  region_id  \
# 688               4          AFG  Afghanistan          4
# 698               4          AFG  Afghanistan          4
# 1007              4          AFG  Afghanistan          4
# 1047              4          AFG  Afghanistan          4
# 1189            728          SSD  South Sudan          5
# ...             ...          ...          ...        ...
# 1173443         430          LBR      Liberia          5
# 1173451           4          AFG  Afghanistan          4
# 1173609         586          PAK     Pakistan          4
# 1173632         760          SYR        Syria          3
# 1174057           4          AFG  Afghanistan          4
#
#                           region_name  income_group_id  \
# 688            South and Central Asia              1.0
# 698            South and Central Asia              1.0
# 1007           South and Central Asia              1.0
# ...

# %%
country_order =test.sort_values("country_name")
country_order

# %%
year = test.set_index('country_code')
year.sort_index()
# Out:
#               country_id country_name  region_id             region_name  \
# country_code
# AFG                    4  Afghanistan          4  South and Central Asia
# AFG                    4  Afghanistan          4  South and Central Asia
# AFG                    4  Afghanistan          4  South and Central Asia
# AFG                    4  Afghanistan          4  South and Central Asia
# AFG                    4  Afghanistan          4  South and Central Asia
# ...                  ...          ...        ...                     ...
# ZWE                  716     Zimbabwe          5      Sub-Saharan Africa
# ZWE                  716     Zimbabwe          5      Sub-Saharan Africa
# ZWE                  716     Zimbabwe          5      Sub-Saharan Africa
# ZWE                  716     Zimbabwe          5      Sub-Saharan Africa
# ZWE                  716     Zimbabwe          5      Sub-Saharan Africa
#
#               income_group_id   income_group_name income_group_acronym  \
# ...

# %%
latlong = "Resources/latlongfinal.csv"

# %%
lldf = pd.read_csv(latlong)
lldf
# Out:
#     Country_Code   latitude   longitude               name country
# 0            AFG  33.939110   67.709953        Afghanistan      AF
# 1            ALB  41.153332   20.168331            Albania      AL
# 2            DZA  28.033886    1.659626            Algeria      DZ
# 3            ASM -14.270972 -170.132217     American Samoa      AS
# 4            AND  42.546245    1.601554            Andorra      AD
# ..           ...        ...         ...                ...     ...
# 230          WLF -13.768752 -177.156097  Wallis and Futuna      WF
# 231          ESH  24.215527  -12.885834     Western Sahara      EH
# 232          YEM  15.552727   48.516388              Yemen      YE
# 233          ZMB -13.133897   27.849332             Zambia      ZM
# 234          ZWE -19.015438   29.154857           Zimbabwe      ZW
#
# [235 rows x 5 columns]

# %%
latdf = pd.DataFrame(lldf)
clean =latdf.drop(["name", "country"], axis=1)

# %%
renamed = clean.rename(columns = {"Country_Code":"country_code"})

# %%
inner_join = pd.merge(year,  
                      renamed,  
                      on ='country_code',  
                      how ='inner') 
inner_join
# Out:
#       country_code  country_id country_name  region_id  \
# 0              AFG           4  Afghanistan          4
# 1              AFG           4  Afghanistan          4
# 2              AFG           4  Afghanistan          4
# 3              AFG           4  Afghanistan          4
# 4              AFG           4  Afghanistan          4
# ...            ...         ...          ...        ...
# 68623          GRD         308      Grenada          6
# 68624          DNK         208      Denmark          2
# 68625          DNK         208      Denmark          2
# 68626          TUV         798       Tuvalu          1
# 68627          LVA         428       Latvia          2
#
#                   region_name  income_group_id            income_group_name  \
# 0      South and Central Asia              1.0           Low Income Country
# 1      South and Central Asia              1.0           Low Income Country
# ...

# %%
inner_join.to_csv("cleaned_dataset.csv")

# %%
_
