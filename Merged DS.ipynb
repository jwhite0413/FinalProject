# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = "Resources/population.csv"

# %%
population = pd.read_csv(data)
df = pd.DataFrame(population)
df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
df_filtered = df[['Country Name', 'Country Code', 'Indicator Name',
                   '2015', '2016', '2017', '2018', '2019']]
df_filtered
# Out:
#      Country Name Country Code     Indicator Name        2015        2016  \
# 0           Aruba          ABW  Population, total    104341.0    104872.0
# 1     Afghanistan          AFG  Population, total  34413603.0  35383128.0
# 2          Angola          AGO  Population, total  27884381.0  28842484.0
# 3         Albania          ALB  Population, total   2880703.0   2876101.0
# 4         Andorra          AND  Population, total     78011.0     77297.0
# ..            ...          ...                ...         ...         ...
# 259        Kosovo          XKX  Population, total   1788196.0   1777557.0
# 260   Yemen, Rep.          YEM  Population, total  26497889.0  27168210.0
# 261  South Africa          ZAF  Population, total  55386367.0  56203654.0
# 262        Zambia          ZMB  Population, total  15879361.0  16363507.0
# 263      Zimbabwe          ZWE  Population, total  13814629.0  14030390.0
#
#            2017        2018        2019
# ...

# %%
df_population = df_filtered.rename(columns = {"Country Code":"country_code",
                                        "Country Name": 'country_name',
                                        "Indicator Name": 'indicator_name'})
df_population
# Out:
#      country_name country_code     indicator_name        2015        2016  \
# 0           Aruba          ABW  Population, total    104341.0    104872.0
# 1     Afghanistan          AFG  Population, total  34413603.0  35383128.0
# 2          Angola          AGO  Population, total  27884381.0  28842484.0
# 3         Albania          ALB  Population, total   2880703.0   2876101.0
# 4         Andorra          AND  Population, total     78011.0     77297.0
# ..            ...          ...                ...         ...         ...
# 259        Kosovo          XKX  Population, total   1788196.0   1777557.0
# 260   Yemen, Rep.          YEM  Population, total  26497889.0  27168210.0
# 261  South Africa          ZAF  Population, total  55386367.0  56203654.0
# 262        Zambia          ZMB  Population, total  15879361.0  16363507.0
# 263      Zimbabwe          ZWE  Population, total  13814629.0  14030390.0
#
#            2017        2018        2019
# ...

# %%
df_population.to_csv ('population_filtered.csv', index=False)

# %%
filepath = "Resources/cleaned_dataset.csv"
dataset = pd.read_csv(filepath)
dataset
# Out:
#        Unnamed: 0 country_code  country_id country_name  region_id  \
# 0               0          AFG           4  Afghanistan          4
# 1               1          AFG           4  Afghanistan          4
# 2               2          AFG           4  Afghanistan          4
# 3               3          AFG           4  Afghanistan          4
# 4               4          AFG           4  Afghanistan          4
# ...           ...          ...         ...          ...        ...
# 82849       82849          GRD         308      Grenada          6
# 82850       82850          AUS          36    Australia          1
# 82851       82851          AUS          36    Australia          1
# 82852       82852          DNK         208      Denmark          2
# 82853       82853          DNK         208      Denmark          2
#
#                   region_name  income_group_id            income_group_name  \
# 0      South and Central Asia              1.0           Low Income Country
# ...

# %%
merged_df = pd.merge(dataset, df_population, how = 'left', 
                     on=['country_code', 'country_name'])
merged_df
# Out:
#        Unnamed: 0 country_code  country_id country_name  region_id  \
# 0               0          AFG           4  Afghanistan          4
# 1               1          AFG           4  Afghanistan          4
# 2               2          AFG           4  Afghanistan          4
# 3               3          AFG           4  Afghanistan          4
# 4               4          AFG           4  Afghanistan          4
# ...           ...          ...         ...          ...        ...
# 82849       82849          GRD         308      Grenada          6
# 82850       82850          AUS          36    Australia          1
# 82851       82851          AUS          36    Australia          1
# 82852       82852          DNK         208      Denmark          2
# 82853       82853          DNK         208      Denmark          2
#
#                   region_name  income_group_id            income_group_name  \
# 0      South and Central Asia              1.0           Low Income Country
# ...

# %%
merged_df.to_csv('merged_dataset.csv')
