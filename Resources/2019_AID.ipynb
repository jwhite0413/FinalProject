# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = "Resources/chopped_dataset2019.csv"
data2 = "Resources/population.csv"

# %%
yearly = pd.read_csv(data)
yearly_df = pd.DataFrame(yearly)
yearly_df.head()
# Out:
#   country_code Country Name     dac_category_name  \
# 0          AFG  Afghanistan            Governance
# 1          AFG  Afghanistan            Governance
# 2          AFG  Afghanistan        Infrastructure
# 3          AFG  Afghanistan  Administrative Costs
# 4          AFG  Afghanistan            Governance
#
#                  dac_sector_name  fiscal_year  constant_amount  latitude  \
# 0   Government and Civil Society         2019        244314589  33.93911
# 1   Government and Civil Society         2019        150000000  33.93911
# 2                         Energy         2019         61857148  33.93911
# 3             Operating Expenses         2019         48160560  33.93911
# 4  Conflict, Peace, and Security         2019         32797036  33.93911
#
#    longitude        2019
# 0  67.709953  38041754.0
# 1  67.709953  38041754.0
# 2  67.709953  38041754.0
# 3  67.709953  38041754.0
# 4  67.709953  38041754.0

# %%
grouped_yearly_df = yearly_df.groupby(['country_code'])

grouped_yearly_df.count().head(10)
# Out:
#               Country Name  dac_category_name  dac_sector_name  fiscal_year  \
# country_code
# AFG                    300                300              300          300
# AGO                     43                 43               43           43
# ALB                     39                 39               39           39
# ARG                      2                  2                2            2
# ARM                     75                 75               75           75
# AZE                     29                 29               29           29
# BDI                     63                 63               63           63
# BEN                     92                 92               92           92
# BFA                     65                 65               65           65
# BGD                    360                360              360          360
#
#               constant_amount  latitude  longitude  2019
# country_code
# ...

# %%
ConstantAmount_df = pd.DataFrame(
    grouped_yearly_df["constant_amount"].sum())

ConstantAmount_df.head(10)
# Out:
#               constant_amount
# country_code
# AFG                1306748064
# AGO                  62478046
# ALB                  13397587
# ARG                    668956
# ARM                  21011799
# AZE                   8341446
# BDI                  44579914
# BEN                  49608215
# BFA                  79928341
# BGD                 259652215

# %%
population = pd.read_csv(data2)
df = pd.DataFrame(population)
df.head()
# Out:
#   Country Name country_code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
df_filtered = df[['country_code', 'Country Name', '2019']]

df_filtered
# Out:
#     country_code  Country Name        2019
# 0            ABW         Aruba    106314.0
# 1            AFG   Afghanistan  38041754.0
# 2            AGO        Angola  31825295.0
# 3            ALB       Albania   2854191.0
# 4            AND       Andorra     77142.0
# ..           ...           ...         ...
# 259          XKX        Kosovo   1794248.0
# 260          YEM   Yemen, Rep.  29161922.0
# 261          ZAF  South Africa  58558270.0
# 262          ZMB        Zambia  17861030.0
# 263          ZWE      Zimbabwe  14645468.0
#
# [264 rows x 3 columns]

# %%
merged_df = pd.merge(df_filtered, ConstantAmount_df, how = 'left', 
                     on=['country_code'])
merged_df
# Out:
#     country_code  Country Name        2019  constant_amount
# 0            ABW         Aruba    106314.0              NaN
# 1            AFG   Afghanistan  38041754.0     1.306748e+09
# 2            AGO        Angola  31825295.0     6.247805e+07
# 3            ALB       Albania   2854191.0     1.339759e+07
# 4            AND       Andorra     77142.0              NaN
# ..           ...           ...         ...              ...
# 259          XKX        Kosovo   1794248.0              NaN
# 260          YEM   Yemen, Rep.  29161922.0     1.418689e+08
# 261          ZAF  South Africa  58558270.0     2.086308e+08
# 262          ZMB        Zambia  17861030.0     4.056163e+08
# 263          ZWE      Zimbabwe  14645468.0     2.068341e+08
#
# [264 rows x 4 columns]

# %%
merged_df = merged_df.rename(columns= {'country_code': 'Country Code', 'constant_amount': '2019 AID' })

# %%
merged_df.to_csv('2019_AID.csv')
